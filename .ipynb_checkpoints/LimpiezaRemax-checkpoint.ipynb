# %%
import pandas as pd
import matplotlib.pylab as plt

# %%
file='C:\\Users\\ADMIN\\Desktop\\prueba1\\Remax_Venta.csv'

# %%
df = pd.read_csv(file)

# %%
df.head(10)
# Out:
#                   Tipo de Inmueble                           Direccion  \
# 0    DEPARTAMENTO FLAT EN ALQUILER              Lima, Lima, San Miguel
# 1             CASA URBANA EN VENTA  Lima, Lima, San Juan de Lurigancho
# 2  DEPARTAMENTO DUPLEX EN ALQUILER              Lima, Lima, Miraflores
# 3             CASA URBANA EN VENTA             Lima, Lima, La Victoria
# 4      TERRENO INDUSTRIAL EN VENTA                 Piura, Paita, Colan
# 5              ALMACÉN EN ALQUILER                   Lima, Lima, Lince
# 6     DEPARTAMENTO DUPLEX EN VENTA              Lima, Lima, Miraflores
# 7       DEPARTAMENTO FLAT EN VENTA       Lima, Lima, Santiago de Surco
# 8          TERRENO URBANO EN VENTA               Lima, Lima, La Molina
# 9       DEPARTAMENTO FLAT EN VENTA  Lima, Lima, San Juan de Lurigancho
#
#                Area Construida                   Area Total       Pisos  \
# 0   Área Construida : 70.26 m²      Área Ocupada : 70.26 m²  Pisos : 13
# ...
